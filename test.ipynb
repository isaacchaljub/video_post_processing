# %%
from post_processing_anomaly_detection import post_processing
import pandas as pd

# %%
data=pd.read_excel('Copy A04 FILA 20A_output_stem_trackable_objects.xlsx')

result=post_processing(data)

with pd.option_context('display.max_rows', None):
    display(result.groupby('object_id').mean())
# Out:
#            centroids_x  centroids_y  aspect_ratio           area  frames  \
# object_id
# 65          425.245283  1023.584906  1.129598e+16  169088.735849    54.0
# 97          573.415094  1075.339623  9.916392e+15  145318.339623    52.0
# 181         493.289474  1112.973684  1.448325e+16  175556.447368    40.0
# 184         710.264706  1091.617647  1.198918e+16  176010.529412    38.0
# 252         420.630435  1155.500000  1.365842e+16  231768.673913    49.0
# 267         525.553191  1144.212766  1.602347e+16  278122.808511    46.0
# 337         460.867647  1247.073529  1.099080e+16  162479.191176    67.0
# 445         477.000000  1148.188679  1.739938e+16  307291.264151    54.0
# 517         533.836066  1196.098361  1.327136e+16  164822.081967    69.0
# 613         520.780000  1166.320000  1.586321e+16  282269.720000    49.0
# 706         536.588235  1087.529412  1.868027e+16  386649.980392    50.0
# 791         483.380952  1102.785714  1.293166e+16  263017.095238    41.0
# ...

# %%
len(result.groupby('object_id').mean()[result.groupby('object_id').mean()['ground_truth'] == 0]), len(result.groupby('object_id').mean()[result.groupby('object_id').mean()['preds']<0.1])
# Out:
# (5, 5)

# %%
data2=pd.read_excel("Copy p22_h44_lado_B_output_stem_trackable_objects.xlsx")

result2=post_processing(data2)

with pd.option_context('display.max_rows', None):
    display(result2.groupby('object_id').mean())
# Out:
#            centroids_x  centroids_y  aspect_ratio           area  frames  \
# object_id
# 4429        596.472973  1242.351351  1.176268e+16  302252.337838    73.0
# 4483        506.943396  1293.207547  8.202190e+15  198144.207547    52.0
# 4528        548.172414  1168.310345  8.363370e+15  349698.034483    28.0
# 4560        547.194444  1127.500000  1.288167e+16  240685.277778    35.0
# 4605        535.418605  1099.674419  8.937663e+15  220134.813953    42.0
# 4643        534.062500  1210.093750  8.862628e+15  207319.437500    31.0
# 4684        562.774194  1131.354839  7.154429e+15  193722.677419    30.0
# 4729        563.333333  1035.916667  8.520757e+15  329247.750000    35.0
# 4765        607.487805  1241.926829  7.478457e+15  174698.000000    40.0
# 4813        619.235294  1189.794118  8.254151e+15  233466.882353    33.0
# 4848        589.138889  1162.361111  9.164698e+15  243835.000000    35.0
# 4882        506.727273  1152.393939  1.202824e+16  277315.484848    34.0
# ...

# %%
len(result2.groupby('object_id').mean()[result2.groupby('object_id').mean()['ground_truth'] == 0]), len(result2.groupby('object_id').mean()[result2.groupby('object_id').mean()['preds']<0.1])
# Out:
# (3, 3)

# %%
data3=pd.read_excel('Copy A04 FILA 01B_output_stem_trackable_objects.xlsx')

result3=post_processing(data3)

with pd.option_context('display.max_rows', None):
    display(result3.groupby('object_id').mean())
# Out:
#            centroids_x  centroids_y  aspect_ratio           area  frames  \
# object_id
# 189         547.017857  1028.982143  1.410350e+16  143038.517857    58.0
# 272         577.451613  1025.225806  1.480127e+16  231825.258065    63.0
# 293         581.363636   861.363636  2.269580e+16  233630.181818    13.0
# 377         526.788462  1128.038462  1.280530e+16  137822.269231    52.0
# 412         496.000000  1159.750000  5.107887e+15  121315.000000    10.0
# 478         512.431034  1101.155172  8.510859e+15  157042.224138    62.0
# 606         532.716049  1116.654321  1.175496e+16   88282.222222    83.0
# 690         571.134615  1088.019231  8.861766e+15  119060.134615    51.0
# 787         490.000000  1222.338462  8.633906e+15  105119.000000    77.0
# 856         580.050000  1172.516667  1.644361e+16  245128.616667    64.0
# 941         552.916667  1190.416667  1.016838e+16  171397.458333    47.0
# 1058        660.274725  1227.252747  9.029480e+15  156023.406593    90.0
# ...

# %%
len(result3.groupby('object_id').mean()[result3.groupby('object_id').mean()['ground_truth'] == 0]), len(result3.groupby('object_id').mean()[result3.groupby('object_id').mean()['preds']<0.1])
# Out:
# (6, 4)

# %%
data4=pd.read_excel('Copy A04 FILA 10A_output_stem_trackable_objects.xlsx')

result4=post_processing(data4)

# en=result4.groupby('object_id').mean()
# en['id']=[i+1 for i in range(len(en))]
with pd.option_context('display.max_rows', None):
    display(result4.groupby('object_id').mean())
    # display(en)
# Out:
#            centroids_x  centroids_y  aspect_ratio           area  frames  \
# object_id
# 5297        484.581818  1077.090909  8.276835e+15  101892.854545    54.0
# 5325        536.200000  1027.830769  9.941840e+15  150390.892308    65.0
# 5410        624.000000  1104.627907  1.176538e+16  183999.941860    85.0
# 5525        533.000000  1249.980392  9.277264e+15  282069.666667    51.0
# 5618        496.322581  1201.258065  1.445789e+16  192521.629032    67.0
# 5759        490.463415  1105.560976  1.205059e+16  277240.341463    40.0
# 5820        619.919540  1332.896552  1.519741e+16  226875.218391    96.0
# 5943        507.260870  1169.152174  1.166382e+16  129204.217391    47.0
# 6030        507.934783  1159.304348  1.599508e+16  321224.782609    45.0
# 6115        530.651163  1214.558140  1.282341e+16  302270.395349    42.0
# 6180        482.402597  1258.012987  1.618636e+16  323429.441558    76.0
# 6293        573.205128  1235.948718  1.280556e+16  259224.589744    41.0
# ...

# %%
len(result4.groupby('object_id').mean()[result4.groupby('object_id').mean()['ground_truth'] == 0]), len(result4.groupby('object_id').mean()[result4.groupby('object_id').mean()['preds']<0.1])
# Out:
# (2, 2)
